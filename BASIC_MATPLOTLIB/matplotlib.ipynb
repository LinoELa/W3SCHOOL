# %%
import matplotlib


print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4,60])

ypoints = np.array([100, 250])

plt.plot(xpoints, ypoints)

plt.show()

# %%
xpoints = np.array([50,60])

ypoints = np.array([40, 60])

plt.plot(xpoints, ypoints)

plt.show()

# %%
xpoints = np.array([4,60])

ypoints = np.array([100, 250])

plt.plot(xpoints, ypoints, "o")

plt.show()

# %%
xpoints = np.array([1, 2, 4, 6])

ypoints = np.array([3, 8, 16,  20])

plt.plot(xpoints, ypoints)

plt.show()

# %%
xpoints = np.array([3, 8, 1, 10])


# ypoints = np.array([100, 250])

plt.plot(xpoints)

plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'P')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'P', c="r")
plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
y3 = np.array([5, 4, 9, 12])

plt.plot(y1)
plt.plot(y2)
plt.plot(y3)


plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
y3 = np.array([5, 4, 9, 12])

plt.plot(y1)
plt.plot(y2)
plt.plot(y3)

plt.grid()


plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
y3 = np.array([5, 4, 9, 12])

# plt.plot(y1)
# plt.plot(y2)
# plt.plot(y3)

plt.bar(y1, y2, y3)


plt.show()
