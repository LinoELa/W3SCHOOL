# %% [markdown]
# Normal Data Distribution - Distribución normal de datos
# In the previous chapter we learned how to create a completely random array, of a given size, and between two given values.
#
# In this chapter we will learn how to create an array where the values are concentrated around a given value.
#
# In probability theory this kind of data distribution is known as the normal data distribution, or the Gaussian data distribution, after the mathematician Carl Friedrich Gauss who came up with the formula of this data distribution

# %%
import numpy
import matplotlib.pyplot as plt


x = numpy.random.normal(5.0, 1.0, 100000) 
plt.hist(x, 100)
plt.show()

# %% [markdown]
# Explicación del histograma
# Usamos el arreglo del método numpy.random.normal(), con 100000 valores, para dibujar un histograma con 100 barras.
#
# Especificamos que el valor medio es 5.0, y la desviación estándar es 1.0.
#
# Lo que significa que los valores deben concentrarse alrededor de 5,0, y rara vez más lejos de 1,0 de la media.
#
# Y como puede ver en el histograma, la mayoría de los valores se sitúan entre 4,0 y 6,0, con un máximo en torno a 5,0.
